# %%
import pandas as pd
df3 = pd.read_csv('idtb_04_bioactivity_data_3class_pIC50.csv')
df3
# Out:
#      Unnamed: 0 molecule_chembl_id  \
# 0             0      CHEMBL4103560
# 1             1      CHEMBL4085628
# 2             2       CHEMBL577784
# 3             3      CHEMBL4096573
# 4             4      CHEMBL4084664
# ..          ...                ...
# 369         369      CHEMBL5203275
# 370         370      CHEMBL5205793
# 371         371      CHEMBL5179510
# 372         372      CHEMBL5174318
# 373         373         CHEMBL1535
#
#                                       canonical_smiles         class       MW  \
# 0                 O=C(NCCO)c1cnn2c(O)cc(-c3ccccc3)nc12      inactive  298.302
# 1                   CNC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12      inactive  268.276
# 2    O=C(NCCCNc1nc(Nc2cccc(NC(=O)N3CCCC3)c2)ncc1I)c...        active  591.479
# 3    O=C(N[C@H]1CCCC[C@H]1C(=O)O)c1cnn2c(O)cc(-c3cc...  intermediate  380.404
# 4         C[C@@H](CO)NC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12      inactive  312.329
# ...

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
with open('molecule.smi', 'r') as file:
    for i, line in enumerate(file):
        if i >= 5:
            break
        print(line.strip())
# Out:
# O=C(NCCO)c1cnn2c(O)cc(-c3ccccc3)nc12	CHEMBL4103560
# CNC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12	CHEMBL4085628
# O=C(NCCCNc1nc(Nc2cccc(NC(=O)N3CCCC3)c2)ncc1I)c1cccs1	CHEMBL577784
# O=C(N[C@H]1CCCC[C@H]1C(=O)O)c1cnn2c(O)cc(-c3ccccc3)nc12	CHEMBL4096573
# C[C@@H](CO)NC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12	CHEMBL4084664

# %%
! type padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! more padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
   import os
   os.system("padel.sh")
# Out:
# 0

# %%
df3_X = pd.read_csv('mordred_descriptors.csv')
df3_X
# Out:
#                 ID                                            ABC  \
# 0    CHEMBL4103560  module 'numpy' has no attribute 'float' (ABC)
# 1    CHEMBL4085628  module 'numpy' has no attribute 'float' (ABC)
# 2     CHEMBL577784  module 'numpy' has no attribute 'float' (ABC)
# 3    CHEMBL4096573  module 'numpy' has no attribute 'float' (ABC)
# 4    CHEMBL4084664  module 'numpy' has no attribute 'float' (ABC)
# ..             ...                                            ...
# 369  CHEMBL5203275  module 'numpy' has no attribute 'float' (ABC)
# 370  CHEMBL5205793  module 'numpy' has no attribute 'float' (ABC)
# 371  CHEMBL5179510  module 'numpy' has no attribute 'float' (ABC)
# 372  CHEMBL5174318  module 'numpy' has no attribute 'float' (ABC)
# 373     CHEMBL1535  module 'numpy' has no attribute 'float' (ABC)
#
#                                                  ABCGG  nAcid  nBase  \
# 0    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# ...

# %%
# Delete the Name columns because we want only the molecular features
# df3_X = df3_X.drop(columns=['Name'])
# df3_X

# df4_X = df3_X.iloc[: , 1:]
# df4_X
df3_X = df3_X.drop(columns=['ID'])
df3_X
# Out:
#                                                ABC  \
# 0    module 'numpy' has no attribute 'float' (ABC)
# 1    module 'numpy' has no attribute 'float' (ABC)
# 2    module 'numpy' has no attribute 'float' (ABC)
# 3    module 'numpy' has no attribute 'float' (ABC)
# 4    module 'numpy' has no attribute 'float' (ABC)
# ..                                             ...
# 369  module 'numpy' has no attribute 'float' (ABC)
# 370  module 'numpy' has no attribute 'float' (ABC)
# 371  module 'numpy' has no attribute 'float' (ABC)
# 372  module 'numpy' has no attribute 'float' (ABC)
# 373  module 'numpy' has no attribute 'float' (ABC)
#
#                                                  ABCGG  nAcid  nBase  \
# 0    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# 1    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# 2    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# 3    module 'numpy' has no attribute 'float' (ABCGG...      1      0
# ...

# %%
df3_Y=df3['pIC50']
df3_Y
# Out:
# 0      4.721246
# 1      4.161151
# 2      7.221849
# 3      5.309804
# 4      4.756962
#          ...
# 369    7.522879
# 370    5.681937
# 371    5.982967
# 372    7.853872
# 373    4.638272
# Name: pIC50, Length: 374, dtype: float64

# %%
df4 = pd.concat([df3_X, df3_Y], axis=1)
df4
# Out:
#                                                ABC  \
# 0    module 'numpy' has no attribute 'float' (ABC)
# 1    module 'numpy' has no attribute 'float' (ABC)
# 2    module 'numpy' has no attribute 'float' (ABC)
# 3    module 'numpy' has no attribute 'float' (ABC)
# 4    module 'numpy' has no attribute 'float' (ABC)
# ..                                             ...
# 369  module 'numpy' has no attribute 'float' (ABC)
# 370  module 'numpy' has no attribute 'float' (ABC)
# 371  module 'numpy' has no attribute 'float' (ABC)
# 372  module 'numpy' has no attribute 'float' (ABC)
# 373  module 'numpy' has no attribute 'float' (ABC)
#
#                                                  ABCGG  nAcid  nBase  \
# 0    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# 1    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# 2    module 'numpy' has no attribute 'float' (ABCGG...      0      0
# 3    module 'numpy' has no attribute 'float' (ABCGG...      1      0
# ...

# %%
df4.to_csv('descriptor_pIC50_values.csv', index=False)
